# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'src', 'mutsuite')))

import configparser
import os
import sys
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from subprocess import call
from collections import defaultdict
from io import StringIO
from mutRun import mutRun
from mutTestHelpers import aggregate_mutations, print_all_mutations_by_sample
from callers.simCaller import SimCaller
from callers.pindelCaller import PindelCaller #additional callers can be implemented and imported here
from callers.mutectCaller import MutectCaller
from callers.lofreqCaller import LofreqCaller
from callers.strelkaCaller import StrelkaCaller
from callers.somaticSniperCaller import SomaticSniperCaller
from callers.vardictCaller import VardictCaller
from callers.varscanCaller import VarscanCaller

from IPython.display import Code

# %% [markdown]
# # First, define the Caller class
# Individual indel callers can implement this class for easy integration into the testing framework.
# As an example, see [pindelCaller.py](pindelCaller.py).

# %%
Code(filename='../src/mutsuite/callers/caller.py', language='python')
# Out:
# class Caller:
#     def __init__(self):
#         """"Instantiate a new caller object.
#         Any variables unique to this caller should be set here.
#         For example, if this caller requires the path to the fastq reference, that should be set here.
#         """
#         pass
#
#     def get_name(self):
#         """Get the name of the caller.
#         This name will be used in output that compares this caller to other callers
#         Returns: A string with a name identifying the caller
#         """
#         pass
#
#     def run_caller(self, sample_bam, control_bam, use_cached=True):
#         """Extract indels from a pair of bams.
#         sample_bam is the bam with simulated indels
#         control_bam is the bam with no simulated indels
#         use_cached is a boolean indicating whether to use cached results if they exist. Cached results are accessible even after 'clean' has been called.
#         Returns: a tuple of:
#             A string with a command to run this indel for this pair of bams
#             A boolean for whether the command has already been completed successfully (and should not be run again)
#         """
#         pass
#
#     def get_results(self, sample_bam, control_bam, use_cached=True):
#         """Extract indel calling results.
#         sample_bam is the bam with simulated indels
#         control_bam is the bam with no simulated indels
#         use_cached is a boolean indicating whether to use cached results if they exist. Cached results are accessible even after 'clean' has been called.
#         run_caller has been run previously. This function collects the results for indel calling by this caller
#         Returns:
#             a dictionary of mutations passing filters: 'LOC TYPE INFO' => count
#                 where TYPE is either 'I' for insertion, 'D' for deletion, 'S' for substitution or 'M' for mixed/multiple
#                 if TYPE is 'I' INFO will be the sequence of the insertion
#                 if TYPE is 'D' INFO will be the length of the deletion
#                 if TYPE is 'S' INFO will be the substituted base
#                 e.g. if a 25bp deletion was observed at position 100 supported by 5 reads, the key would be '100 D 25' and the value would be 5
#                 e.g. if a 2bp insertion of AT was observed at position 50 supported by 3 reads, the key would be '50 I AT' and the value would be 3
#             a dictionary of all mutations: 'LOC TYPE INFO' => Mutation object
#         """
#         pass
#
#     def clean(self, sample_bam, control_bam):
#         """
#         Remove all intermediate files associated with calling mutations for this sample
#         """
#         pass

# %% [markdown]
# ## Read in settings file.
# This settings file contains information required to run this simulation, including the location of the genome edits for simulations, and the bam sources of edited and non-edited reads.

# %%
settingsFile = "simSettings.txt"
Code(filename=settingsFile)
# Out:
# [Simulation]
# depths: 30   # specifies the depths for the simulation, as a comma-separated list
# countMut: 5 # specifies the number of reads to be mutated, as a comma separated list
# addQual: 0       # specifies the addition of quality to all bases (0 means that original quality scores are used)
# reps: 1          # specifies the number of replicates of each depth/pctMut/addQual setting to run
# chr: chr11       # location of genome editing event
# loc: 836297      # location of genome editing event
# FDRtolerance: 10,100,1000 # window sizes for false positive indel calls
# reference: genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa        # location of fastq reference sequence, with bwa alignment files
# sourceBam: data/NA12878/HG001.GRCh38_full_plus_hs38d1_analysis_set_minus_alts.300x.bam # location of bam with unaltered reads
# unalteredBam: 10kbAroundCutsite.BWA.bam # file to write unaltered reads around cut site
# unalteredNamesortedBam: 10kbAroundCutsite.BWA.nameSort.bam # file to write unaltered reads around cut site (namesorted)
# simulateRange: 5000 # A simulated and control sample will be generated with reads within this many bp of 'chr:'loc' as specified above
# onlyInsertSpecificMutation: D1,D2
# mutSimScript: ../src/mutsuite/mutSim.py # location of mutSim.py script and module files.
#
# [Callers]
# gatk_env_command: conda run -n kc_gatk4 bash -c "
# lofreq_env_command: conda run -n kc_lofreq bash -c "
# pindel_env_command: conda run -n kc_pindel bash -c "
# somaticsniper_env_command: conda run -n kc_somaticSniper bash -c "
# strelka_env_command: conda run -n kc_strelka2 bash -c "
# vardict_env_command: conda run -n kc_vardict bash -c "
# varscan_env_command: conda run -n kc_varscan bash -c "
# caller_threads: 20

# %%
if not os.path.isfile(settingsFile):
    raise Exception("Couldn't find settings file")
workFolder = os.path.abspath(settingsFile) + ".output/"
if not os.path.isdir(workFolder):
    os.makedirs(workFolder)
Config = configparser.ConfigParser(inline_comment_prefixes="#")
Config.read(settingsFile)
# Out:
# ['simSettings.txt']

# %% [markdown]
# ## Create simulated samples by replacing reads with those with simulated indels

# %%
samples, simulateReadsCommands = mutRun(Config, workFolder)
if len(simulateReadsCommands) > 0:
        print ("got " + str(len(simulateReadsCommands)) + " commands to simulate samples")
        for command in simulateReadsCommands:
                print('calling command ' + str(command))
                call(command,shell=True)
else:
        print('Finished simulating samples')
# Out:
# Finished simulating samples

# %% [markdown]
# ## Read actual simulated reads
# We use the [SimCaller](simCaller.py) class, which is a special instance of the Caller class, for which the ```get_results``` method is implemented, and recovers the simulated indels inserted into the simulated samples.

# %%
simCaller = SimCaller(Config)
simulated_mutations = {}
for sample_name, simulated_bam, simulated_control in samples:
    sample_simulated_indels, sample_simulated_mutations = simCaller.get_results(simulated_bam, simulated_control)
    simulated_mutations[sample_name] = sample_simulated_mutations
aggregated_simulated_mutations = aggregate_mutations(simulated_mutations)

# %%
aggregated_simulated_mutations
# Out:
# defaultdict(int, {'836295 D 1': 5, '836295 D 2': 5})

# %% [markdown]
# ## Create an array of callers
# Users may implement additional callers. They are instantiated here and added to this list of callers for testing and comparison below.

# %%
Config = configparser.ConfigParser(inline_comment_prefixes="#")
Config.read(settingsFile)

callers = []
pindelCaller = PindelCaller(Config)
callers.append(pindelCaller)
lofreqCaller = LofreqCaller(Config)
callers.append(lofreqCaller)
vardictCaller = VardictCaller(Config)
callers.append(vardictCaller)
somaticsniperCaller = SomaticSniperCaller(Config)
callers.append(somaticsniperCaller)
varscanCaller = VarscanCaller(Config)
callers.append(varscanCaller)
mutectCaller = MutectCaller(Config)
callers.append(mutectCaller)
strelkaCaller = StrelkaCaller(Config)
callers.append(strelkaCaller)

# %% [markdown]
# ## Run a single caller
# Now that the callers are implemented, we can do a test run on single sample. Here, we'll demonstrate the pindelCaller.

# %%
#grab a sample
test_sample_name, test_sample_sim_bam, test_sample_control_bam = samples[-1]
print("Test sample: " + test_sample_name + "\nSimulated bam: " + test_sample_sim_bam + "\nControl bam: " + test_sample_control_bam)
# Out:
# Test sample: sim_d30_p5.0_q0_sD2_r0
# Simulated bam: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam
# Control bam: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam

# %%
#When we execute run_caller, the caller will return the command to run that caller and a boolean for whether the command has already completed successfully.
command, is_finished = pindelCaller.run_caller(test_sample_sim_bam,test_sample_control_bam)
print('Command is: ' + command)
print("is_finished: " + str(is_finished))

if not is_finished:
    call(command,shell=True) #takes a minute to run
# Out:
# Command is: conda run -n kc_pindel bash -c " pindel -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -r false -t false -l false -k false -s false -i /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.pindel/pindel.config -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.pindel/pindel.tmp. -T 20 -c chr11:835197-837397 && pindel2vcf -P /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.pindel/pindel.tmp. -r genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -R genome -d 20101123 -v /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.pindel/pindel.vcf -G -mc 1 && rm -f /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.pindel/pindel.tmp.* &&  touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.pindel/pindel.pindel.finished"
# is_finished: False
# Initializing parameters...
# Pindel version 0.2.5b9, 20160729.
# Loading reference genome ...
# Loading reference genome done.
# Initializing parameters done.
# SearchRegion::SearchRegion
# Processing region: chr11	835197	837397
# Chromosome Size: 135086622
# NumBoxes: 60008	BoxSize: 4509
#
# Looking at chromosome chr11 bases 835197 to 837397 of the bed region: chromosome chr11:835197-837397
# No discordant RP reads in Bamfile /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam
# No discordant RP reads in Bamfile /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam
# Discovery RP: 0
# sorting RP complete.
# Reads_RP.size(): 0
# Modify RP complete.
# adding BD from RP.
# modify and summarize interchr RP.
# adding BD from interChr RP.
# summarize BP as BD complete. Now start sorting BD...
# sorting BD... done.
# external BD events: 0 Added BreakDancer-like events: 0
#
# Insertsize in config: 558
# The number of one end mapped read: 499
# Number of problematic reads in current window:            	1282, + 961 - 321
# Number of split-reads where the close end could be mapped:	499, + 387 - 112
# Percentage of problematic reads with close end mapped:    	+ 40.27% - 34.89%
# BAM file index	0
# Bam file name	/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam
# Number of split-reads so far	499
#
#
# Insertsize in config: 558
# The number of one end mapped read: 1005
# Number of problematic reads in current window:            	2569, + 1926 - 643
# Number of split-reads where the close end could be mapped:	1005, + 780 - 225
# Percentage of problematic reads with close end mapped:    	+ 40.50% - 34.99%
# BAM file index	1
# Bam file name	/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam
# Number of split-reads so far	1005
#
# The number of one end mapped read: 1005
# There are 4137 reads supporting the reference allele.
# There are 1 samples.
# SampleName2Index done
# declaring g_RefCoverageRegion for 1 samples and 22201 positions.
# There are 1005 split-reads for this chromosome region.
#
# There are 0 split-reads mapped by aligner.
# search far ends
# Far end searching completed for this window.
# update FarFragName
# update FarFragName done
# Searching and reporting variations
# Reads already used: 0
# Far ends already mapped 621
# Checksum of far ends: 581451037
# Searching some type of variant, replace this with the correct name in child class ...
# Total: 59	+48	-11
# Sorting and outputing deletions ...
# Deletions: 4
#
# Searching deletion-insertions ...
# Total: 2	+0	-2
# Sorting and outputing deletions with non-template sequences ...
# Added: Sorting and outputing deletions with non-template sequences ...
# deletions with non-template sequences: 0
#
# Reads already used: 61
# Far ends already mapped 621
# Checksum of far ends: 581451037
# Searching some type of variant, replace this with the correct name in child class ...
# Total: 0	+0	-0
# Sorting and outputing short insertions ...
# Short insertions: 0
#
# Total: 1005;	Close_end_found 1005;	Far_end_found 621;	Used	61.
#
# For LI and BP: 384
#
# There are 0 split-reads saved for the next cycle.
#
# InterChromosome_SR.size(): 0
# PreviousChrName:
# Initializing pindel 89 seconds.
# Loading chromosomes 0 seconds.
# Reading in reads + matching close ends 0 seconds.
# Searching far ends 0 seconds.
# Searching and reporting variations 0 seconds.
# Samples:
# 1. .0
# Chromosomes in which SVs have been found:
# 1. chr11
# Scanning chromosome: chr1
# Scanning chromosome: chr2
# Scanning chromosome: chr3
# Scanning chromosome: chr4
# Scanning chromosome: chr5
# Scanning chromosome: chr6
# Scanning chromosome: chr7
# Scanning chromosome: chr8
# Scanning chromosome: chr9
# Scanning chromosome: chr10
# Scanning chromosome: chr11
# Scanning chromosome: chr12
# Scanning chromosome: chr13
# Scanning chromosome: chr14
# Scanning chromosome: chr15
# Scanning chromosome: chr16
# Scanning chromosome: chr17
# Scanning chromosome: chr18
# Scanning chromosome: chr19
# Scanning chromosome: chr20
# Scanning chromosome: chr21
# Scanning chromosome: chr22
# Scanning chromosome: chrX
# Scanning chromosome: chrY
# Scanning chromosome: chrM
# Scanning chromosome: chr1_KI270706v1_random
# Scanning chromosome: chr1_KI270707v1_random
# Scanning chromosome: chr1_KI270708v1_random
# Scanning chromosome: chr1_KI270709v1_random
# Scanning chromosome: chr1_KI270710v1_random
# Scanning chromosome: chr1_KI270711v1_random
# Scanning chromosome: chr1_KI270712v1_random
# Scanning chromosome: chr1_KI270713v1_random
# Scanning chromosome: chr1_KI270714v1_random
# Scanning chromosome: chr2_KI270715v1_random
# Scanning chromosome: chr2_KI270716v1_random
# Scanning chromosome: chr3_GL000221v1_random
# Scanning chromosome: chr4_GL000008v2_random
# Scanning chromosome: chr5_GL000208v1_random
# Scanning chromosome: chr9_KI270717v1_random
# Scanning chromosome: chr9_KI270718v1_random
# Scanning chromosome: chr9_KI270719v1_random
# Scanning chromosome: chr9_KI270720v1_random
# Scanning chromosome: chr11_KI270721v1_random
# Scanning chromosome: chr14_GL000009v2_random
# Scanning chromosome: chr14_GL000225v1_random
# Scanning chromosome: chr14_KI270722v1_random
# Scanning chromosome: chr14_GL000194v1_random
# Scanning chromosome: chr14_KI270723v1_random
# Scanning chromosome: chr14_KI270724v1_random
# Scanning chromosome: chr14_KI270725v1_random
# Scanning chromosome: chr14_KI270726v1_random
# Scanning chromosome: chr15_KI270727v1_random
# Scanning chromosome: chr16_KI270728v1_random
# Scanning chromosome: chr17_GL000205v2_random
# Scanning chromosome: chr17_KI270729v1_random
# Scanning chromosome: chr17_KI270730v1_random
# Scanning chromosome: chr22_KI270731v1_random
# Scanning chromosome: chr22_KI270732v1_random
# Scanning chromosome: chr22_KI270733v1_random
# Scanning chromosome: chr22_KI270734v1_random
# Scanning chromosome: chr22_KI270735v1_random
# Scanning chromosome: chr22_KI270736v1_random
# Scanning chromosome: chr22_KI270737v1_random
# Scanning chromosome: chr22_KI270738v1_random
# Scanning chromosome: chr22_KI270739v1_random
# Scanning chromosome: chrY_KI270740v1_random
# Scanning chromosome: chrUn_KI270302v1
# Scanning chromosome: chrUn_KI270304v1
# Scanning chromosome: chrUn_KI270303v1
# Scanning chromosome: chrUn_KI270305v1
# Scanning chromosome: chrUn_KI270322v1
# Scanning chromosome: chrUn_KI270320v1
# Scanning chromosome: chrUn_KI270310v1
# Scanning chromosome: chrUn_KI270316v1
# Scanning chromosome: chrUn_KI270315v1
# Scanning chromosome: chrUn_KI270312v1
# Scanning chromosome: chrUn_KI270311v1
# Scanning chromosome: chrUn_KI270317v1
# Scanning chromosome: chrUn_KI270412v1
# Scanning chromosome: chrUn_KI270411v1
# Scanning chromosome: chrUn_KI270414v1
# Scanning chromosome: chrUn_KI270419v1
# Scanning chromosome: chrUn_KI270418v1
# Scanning chromosome: chrUn_KI270420v1
# Scanning chromosome: chrUn_KI270424v1
# Scanning chromosome: chrUn_KI270417v1
# Scanning chromosome: chrUn_KI270422v1
# Scanning chromosome: chrUn_KI270423v1
# Scanning chromosome: chrUn_KI270425v1
# Scanning chromosome: chrUn_KI270429v1
# Scanning chromosome: chrUn_KI270442v1
# Scanning chromosome: chrUn_KI270466v1
# Scanning chromosome: chrUn_KI270465v1
# Scanning chromosome: chrUn_KI270467v1
# Scanning chromosome: chrUn_KI270435v1
# Scanning chromosome: chrUn_KI270438v1
# Scanning chromosome: chrUn_KI270468v1
# Scanning chromosome: chrUn_KI270510v1
# Scanning chromosome: chrUn_KI270509v1
# Scanning chromosome: chrUn_KI270518v1
# Scanning chromosome: chrUn_KI270508v1
# Scanning chromosome: chrUn_KI270516v1
# Scanning chromosome: chrUn_KI270512v1
# Scanning chromosome: chrUn_KI270519v1
# Scanning chromosome: chrUn_KI270522v1
# Scanning chromosome: chrUn_KI270511v1
# Scanning chromosome: chrUn_KI270515v1
# Scanning chromosome: chrUn_KI270507v1
# Scanning chromosome: chrUn_KI270517v1
# Scanning chromosome: chrUn_KI270529v1
# Scanning chromosome: chrUn_KI270528v1
# Scanning chromosome: chrUn_KI270530v1
# Scanning chromosome: chrUn_KI270539v1
# Scanning chromosome: chrUn_KI270538v1
# Scanning chromosome: chrUn_KI270544v1
# Scanning chromosome: chrUn_KI270548v1
# Scanning chromosome: chrUn_KI270583v1
# Scanning chromosome: chrUn_KI270587v1
# Scanning chromosome: chrUn_KI270580v1
# Scanning chromosome: chrUn_KI270581v1
# Scanning chromosome: chrUn_KI270579v1
# Scanning chromosome: chrUn_KI270589v1
# Scanning chromosome: chrUn_KI270590v1
# Scanning chromosome: chrUn_KI270584v1
# Scanning chromosome: chrUn_KI270582v1
# Scanning chromosome: chrUn_KI270588v1
# Scanning chromosome: chrUn_KI270593v1
# Scanning chromosome: chrUn_KI270591v1
# Scanning chromosome: chrUn_KI270330v1
# Scanning chromosome: chrUn_KI270329v1
# Scanning chromosome: chrUn_KI270334v1
# Scanning chromosome: chrUn_KI270333v1
# Scanning chromosome: chrUn_KI270335v1
# Scanning chromosome: chrUn_KI270338v1
# Scanning chromosome: chrUn_KI270340v1
# Scanning chromosome: chrUn_KI270336v1
# Scanning chromosome: chrUn_KI270337v1
# Scanning chromosome: chrUn_KI270363v1
# Scanning chromosome: chrUn_KI270364v1
# Scanning chromosome: chrUn_KI270362v1
# Scanning chromosome: chrUn_KI270366v1
# Scanning chromosome: chrUn_KI270378v1
# Scanning chromosome: chrUn_KI270379v1
# Scanning chromosome: chrUn_KI270389v1
# Scanning chromosome: chrUn_KI270390v1
# Scanning chromosome: chrUn_KI270387v1
# Scanning chromosome: chrUn_KI270395v1
# Scanning chromosome: chrUn_KI270396v1
# Scanning chromosome: chrUn_KI270388v1
# Scanning chromosome: chrUn_KI270394v1
# Scanning chromosome: chrUn_KI270386v1
# Scanning chromosome: chrUn_KI270391v1
# Scanning chromosome: chrUn_KI270383v1
# Scanning chromosome: chrUn_KI270393v1
# Scanning chromosome: chrUn_KI270384v1
# Scanning chromosome: chrUn_KI270392v1
# Scanning chromosome: chrUn_KI270381v1
# Scanning chromosome: chrUn_KI270385v1
# Scanning chromosome: chrUn_KI270382v1
# Scanning chromosome: chrUn_KI270376v1
# Scanning chromosome: chrUn_KI270374v1
# Scanning chromosome: chrUn_KI270372v1
# Scanning chromosome: chrUn_KI270373v1
# Scanning chromosome: chrUn_KI270375v1
# Scanning chromosome: chrUn_KI270371v1
# Scanning chromosome: chrUn_KI270448v1
# Scanning chromosome: chrUn_KI270521v1
# Scanning chromosome: chrUn_GL000195v1
# Scanning chromosome: chrUn_GL000219v1
# Scanning chromosome: chrUn_GL000220v1
# Scanning chromosome: chrUn_GL000224v1
# Scanning chromosome: chrUn_KI270741v1
# Scanning chromosome: chrUn_GL000226v1
# Scanning chromosome: chrUn_GL000213v1
# Scanning chromosome: chrUn_KI270743v1
# Scanning chromosome: chrUn_KI270744v1
# Scanning chromosome: chrUn_KI270745v1
# Scanning chromosome: chrUn_KI270746v1
# Scanning chromosome: chrUn_KI270747v1
# Scanning chromosome: chrUn_KI270748v1
# Scanning chromosome: chrUn_KI270749v1
# Scanning chromosome: chrUn_KI270750v1
# Scanning chromosome: chrUn_KI270751v1
# Scanning chromosome: chrUn_KI270752v1
# Scanning chromosome: chrUn_KI270753v1
# Scanning chromosome: chrUn_KI270754v1
# Scanning chromosome: chrUn_KI270755v1
# Scanning chromosome: chrUn_KI270756v1
# Scanning chromosome: chrUn_KI270757v1
# Scanning chromosome: chrUn_GL000214v1
# Scanning chromosome: chrUn_KI270742v1
# Scanning chromosome: chrUn_GL000216v2
# Scanning chromosome: chrUn_GL000218v1
# Scanning chromosome: chrEBV
# No reads for chromosome chr1, skipping it.
# Removing chromosome chr1 from memory.
# No reads for chromosome chr2, skipping it.
# Removing chromosome chr2 from memory.
# No reads for chromosome chr3, skipping it.
# Removing chromosome chr3 from memory.
# No reads for chromosome chr4, skipping it.
# Removing chromosome chr4 from memory.
# No reads for chromosome chr5, skipping it.
# Removing chromosome chr5 from memory.
# No reads for chromosome chr6, skipping it.
# Removing chromosome chr6 from memory.
# No reads for chromosome chr7, skipping it.
# Removing chromosome chr7 from memory.
# No reads for chromosome chr8, skipping it.
# Removing chromosome chr8 from memory.
# No reads for chromosome chr9, skipping it.
# Removing chromosome chr9 from memory.
# No reads for chromosome chr10, skipping it.
# Removing chromosome chr10 from memory.
# Processing chromosome chr11
# reportSVsInChromosome: start reading region.
# Reading region 0-300000000
# Reading chromosome chr11 into memory.
# Total reads: 4
# Sorting completed
# Removing chromosome chr11 from memory.
# No reads for chromosome chr12, skipping it.
# Removing chromosome chr12 from memory.
# No reads for chromosome chr13, skipping it.
# Removing chromosome chr13 from memory.
# No reads for chromosome chr14, skipping it.
# Removing chromosome chr14 from memory.
# No reads for chromosome chr15, skipping it.
# Removing chromosome chr15 from memory.
# No reads for chromosome chr16, skipping it.
# Removing chromosome chr16 from memory.
# No reads for chromosome chr17, skipping it.
# Removing chromosome chr17 from memory.
# No reads for chromosome chr18, skipping it.
# Removing chromosome chr18 from memory.
# No reads for chromosome chr19, skipping it.
# Removing chromosome chr19 from memory.
# No reads for chromosome chr20, skipping it.
# Removing chromosome chr20 from memory.
# No reads for chromosome chr21, skipping it.
# Removing chromosome chr21 from memory.
# No reads for chromosome chr22, skipping it.
# Removing chromosome chr22 from memory.
# No reads for chromosome chrX, skipping it.
# Removing chromosome chrX from memory.
# No reads for chromosome chrY, skipping it.
# Removing chromosome chrY from memory.
# No reads for chromosome chrM, skipping it.
# Removing chromosome chrM from memory.
# No reads for chromosome chr1_KI270706v1_random, skipping it.
# Removing chromosome chr1_KI270706v1_random from memory.
# No reads for chromosome chr1_KI270707v1_random, skipping it.
# Removing chromosome chr1_KI270707v1_random from memory.
# No reads for chromosome chr1_KI270708v1_random, skipping it.
# Removing chromosome chr1_KI270708v1_random from memory.
# No reads for chromosome chr1_KI270709v1_random, skipping it.
# Removing chromosome chr1_KI270709v1_random from memory.
# No reads for chromosome chr1_KI270710v1_random, skipping it.
# Removing chromosome chr1_KI270710v1_random from memory.
# No reads for chromosome chr1_KI270711v1_random, skipping it.
# Removing chromosome chr1_KI270711v1_random from memory.
# No reads for chromosome chr1_KI270712v1_random, skipping it.
# Removing chromosome chr1_KI270712v1_random from memory.
# No reads for chromosome chr1_KI270713v1_random, skipping it.
# Removing chromosome chr1_KI270713v1_random from memory.
# No reads for chromosome chr1_KI270714v1_random, skipping it.
# Removing chromosome chr1_KI270714v1_random from memory.
# No reads for chromosome chr2_KI270715v1_random, skipping it.
# Removing chromosome chr2_KI270715v1_random from memory.
# No reads for chromosome chr2_KI270716v1_random, skipping it.
# Removing chromosome chr2_KI270716v1_random from memory.
# No reads for chromosome chr3_GL000221v1_random, skipping it.
# Removing chromosome chr3_GL000221v1_random from memory.
# No reads for chromosome chr4_GL000008v2_random, skipping it.
# Removing chromosome chr4_GL000008v2_random from memory.
# No reads for chromosome chr5_GL000208v1_random, skipping it.
# Removing chromosome chr5_GL000208v1_random from memory.
# No reads for chromosome chr9_KI270717v1_random, skipping it.
# Removing chromosome chr9_KI270717v1_random from memory.
# No reads for chromosome chr9_KI270718v1_random, skipping it.
# Removing chromosome chr9_KI270718v1_random from memory.
# No reads for chromosome chr9_KI270719v1_random, skipping it.
# Removing chromosome chr9_KI270719v1_random from memory.
# No reads for chromosome chr9_KI270720v1_random, skipping it.
# Removing chromosome chr9_KI270720v1_random from memory.
# No reads for chromosome chr11_KI270721v1_random, skipping it.
# Removing chromosome chr11_KI270721v1_random from memory.
# No reads for chromosome chr14_GL000009v2_random, skipping it.
# Removing chromosome chr14_GL000009v2_random from memory.
# No reads for chromosome chr14_GL000225v1_random, skipping it.
# Removing chromosome chr14_GL000225v1_random from memory.
# No reads for chromosome chr14_KI270722v1_random, skipping it.
# Removing chromosome chr14_KI270722v1_random from memory.
# No reads for chromosome chr14_GL000194v1_random, skipping it.
# Removing chromosome chr14_GL000194v1_random from memory.
# No reads for chromosome chr14_KI270723v1_random, skipping it.
# Removing chromosome chr14_KI270723v1_random from memory.
# No reads for chromosome chr14_KI270724v1_random, skipping it.
# Removing chromosome chr14_KI270724v1_random from memory.
# No reads for chromosome chr14_KI270725v1_random, skipping it.
# Removing chromosome chr14_KI270725v1_random from memory.
# No reads for chromosome chr14_KI270726v1_random, skipping it.
# Removing chromosome chr14_KI270726v1_random from memory.
# No reads for chromosome chr15_KI270727v1_random, skipping it.
# Removing chromosome chr15_KI270727v1_random from memory.
# No reads for chromosome chr16_KI270728v1_random, skipping it.
# Removing chromosome chr16_KI270728v1_random from memory.
# No reads for chromosome chr17_GL000205v2_random, skipping it.
# Removing chromosome chr17_GL000205v2_random from memory.
# No reads for chromosome chr17_KI270729v1_random, skipping it.
# Removing chromosome chr17_KI270729v1_random from memory.
# No reads for chromosome chr17_KI270730v1_random, skipping it.
# Removing chromosome chr17_KI270730v1_random from memory.
# No reads for chromosome chr22_KI270731v1_random, skipping it.
# Removing chromosome chr22_KI270731v1_random from memory.
# No reads for chromosome chr22_KI270732v1_random, skipping it.
# Removing chromosome chr22_KI270732v1_random from memory.
# No reads for chromosome chr22_KI270733v1_random, skipping it.
# Removing chromosome chr22_KI270733v1_random from memory.
# No reads for chromosome chr22_KI270734v1_random, skipping it.
# Removing chromosome chr22_KI270734v1_random from memory.
# No reads for chromosome chr22_KI270735v1_random, skipping it.
# Removing chromosome chr22_KI270735v1_random from memory.
# No reads for chromosome chr22_KI270736v1_random, skipping it.
# Removing chromosome chr22_KI270736v1_random from memory.
# No reads for chromosome chr22_KI270737v1_random, skipping it.
# Removing chromosome chr22_KI270737v1_random from memory.
# No reads for chromosome chr22_KI270738v1_random, skipping it.
# Removing chromosome chr22_KI270738v1_random from memory.
# No reads for chromosome chr22_KI270739v1_random, skipping it.
# Removing chromosome chr22_KI270739v1_random from memory.
# No reads for chromosome chrY_KI270740v1_random, skipping it.
# Removing chromosome chrY_KI270740v1_random from memory.
# No reads for chromosome chrUn_KI270302v1, skipping it.
# Removing chromosome chrUn_KI270302v1 from memory.
# No reads for chromosome chrUn_KI270304v1, skipping it.
# Removing chromosome chrUn_KI270304v1 from memory.
# No reads for chromosome chrUn_KI270303v1, skipping it.
# Removing chromosome chrUn_KI270303v1 from memory.
# No reads for chromosome chrUn_KI270305v1, skipping it.
# Removing chromosome chrUn_KI270305v1 from memory.
# No reads for chromosome chrUn_KI270322v1, skipping it.
# Removing chromosome chrUn_KI270322v1 from memory.
# No reads for chromosome chrUn_KI270320v1, skipping it.
# Removing chromosome chrUn_KI270320v1 from memory.
# No reads for chromosome chrUn_KI270310v1, skipping it.
# Removing chromosome chrUn_KI270310v1 from memory.
# No reads for chromosome chrUn_KI270316v1, skipping it.
# Removing chromosome chrUn_KI270316v1 from memory.
# No reads for chromosome chrUn_KI270315v1, skipping it.
# Removing chromosome chrUn_KI270315v1 from memory.
# No reads for chromosome chrUn_KI270312v1, skipping it.
# Removing chromosome chrUn_KI270312v1 from memory.
# No reads for chromosome chrUn_KI270311v1, skipping it.
# Removing chromosome chrUn_KI270311v1 from memory.
# No reads for chromosome chrUn_KI270317v1, skipping it.
# Removing chromosome chrUn_KI270317v1 from memory.
# No reads for chromosome chrUn_KI270412v1, skipping it.
# Removing chromosome chrUn_KI270412v1 from memory.
# No reads for chromosome chrUn_KI270411v1, skipping it.
# Removing chromosome chrUn_KI270411v1 from memory.
# No reads for chromosome chrUn_KI270414v1, skipping it.
# Removing chromosome chrUn_KI270414v1 from memory.
# No reads for chromosome chrUn_KI270419v1, skipping it.
# Removing chromosome chrUn_KI270419v1 from memory.
# No reads for chromosome chrUn_KI270418v1, skipping it.
# Removing chromosome chrUn_KI270418v1 from memory.
# No reads for chromosome chrUn_KI270420v1, skipping it.
# Removing chromosome chrUn_KI270420v1 from memory.
# No reads for chromosome chrUn_KI270424v1, skipping it.
# Removing chromosome chrUn_KI270424v1 from memory.
# No reads for chromosome chrUn_KI270417v1, skipping it.
# Removing chromosome chrUn_KI270417v1 from memory.
# No reads for chromosome chrUn_KI270422v1, skipping it.
# Removing chromosome chrUn_KI270422v1 from memory.
# No reads for chromosome chrUn_KI270423v1, skipping it.
# Removing chromosome chrUn_KI270423v1 from memory.
# No reads for chromosome chrUn_KI270425v1, skipping it.
# Removing chromosome chrUn_KI270425v1 from memory.
# No reads for chromosome chrUn_KI270429v1, skipping it.
# Removing chromosome chrUn_KI270429v1 from memory.
# No reads for chromosome chrUn_KI270442v1, skipping it.
# Removing chromosome chrUn_KI270442v1 from memory.
# No reads for chromosome chrUn_KI270466v1, skipping it.
# Removing chromosome chrUn_KI270466v1 from memory.
# No reads for chromosome chrUn_KI270465v1, skipping it.
# Removing chromosome chrUn_KI270465v1 from memory.
# No reads for chromosome chrUn_KI270467v1, skipping it.
# Removing chromosome chrUn_KI270467v1 from memory.
# No reads for chromosome chrUn_KI270435v1, skipping it.
# Removing chromosome chrUn_KI270435v1 from memory.
# No reads for chromosome chrUn_KI270438v1, skipping it.
# Removing chromosome chrUn_KI270438v1 from memory.
# No reads for chromosome chrUn_KI270468v1, skipping it.
# Removing chromosome chrUn_KI270468v1 from memory.
# No reads for chromosome chrUn_KI270510v1, skipping it.
# Removing chromosome chrUn_KI270510v1 from memory.
# No reads for chromosome chrUn_KI270509v1, skipping it.
# Removing chromosome chrUn_KI270509v1 from memory.
# No reads for chromosome chrUn_KI270518v1, skipping it.
# Removing chromosome chrUn_KI270518v1 from memory.
# No reads for chromosome chrUn_KI270508v1, skipping it.
# Removing chromosome chrUn_KI270508v1 from memory.
# No reads for chromosome chrUn_KI270516v1, skipping it.
# Removing chromosome chrUn_KI270516v1 from memory.
# No reads for chromosome chrUn_KI270512v1, skipping it.
# Removing chromosome chrUn_KI270512v1 from memory.
# No reads for chromosome chrUn_KI270519v1, skipping it.
# Removing chromosome chrUn_KI270519v1 from memory.
# No reads for chromosome chrUn_KI270522v1, skipping it.
# Removing chromosome chrUn_KI270522v1 from memory.
# No reads for chromosome chrUn_KI270511v1, skipping it.
# Removing chromosome chrUn_KI270511v1 from memory.
# No reads for chromosome chrUn_KI270515v1, skipping it.
# Removing chromosome chrUn_KI270515v1 from memory.
# No reads for chromosome chrUn_KI270507v1, skipping it.
# Removing chromosome chrUn_KI270507v1 from memory.
# No reads for chromosome chrUn_KI270517v1, skipping it.
# Removing chromosome chrUn_KI270517v1 from memory.
# No reads for chromosome chrUn_KI270529v1, skipping it.
# Removing chromosome chrUn_KI270529v1 from memory.
# No reads for chromosome chrUn_KI270528v1, skipping it.
# Removing chromosome chrUn_KI270528v1 from memory.
# No reads for chromosome chrUn_KI270530v1, skipping it.
# Removing chromosome chrUn_KI270530v1 from memory.
# No reads for chromosome chrUn_KI270539v1, skipping it.
# Removing chromosome chrUn_KI270539v1 from memory.
# No reads for chromosome chrUn_KI270538v1, skipping it.
# Removing chromosome chrUn_KI270538v1 from memory.
# No reads for chromosome chrUn_KI270544v1, skipping it.
# Removing chromosome chrUn_KI270544v1 from memory.
# No reads for chromosome chrUn_KI270548v1, skipping it.
# Removing chromosome chrUn_KI270548v1 from memory.
# No reads for chromosome chrUn_KI270583v1, skipping it.
# Removing chromosome chrUn_KI270583v1 from memory.
# No reads for chromosome chrUn_KI270587v1, skipping it.
# Removing chromosome chrUn_KI270587v1 from memory.
# No reads for chromosome chrUn_KI270580v1, skipping it.
# Removing chromosome chrUn_KI270580v1 from memory.
# No reads for chromosome chrUn_KI270581v1, skipping it.
# Removing chromosome chrUn_KI270581v1 from memory.
# No reads for chromosome chrUn_KI270579v1, skipping it.
# Removing chromosome chrUn_KI270579v1 from memory.
# No reads for chromosome chrUn_KI270589v1, skipping it.
# Removing chromosome chrUn_KI270589v1 from memory.
# No reads for chromosome chrUn_KI270590v1, skipping it.
# Removing chromosome chrUn_KI270590v1 from memory.
# No reads for chromosome chrUn_KI270584v1, skipping it.
# Removing chromosome chrUn_KI270584v1 from memory.
# No reads for chromosome chrUn_KI270582v1, skipping it.
# Removing chromosome chrUn_KI270582v1 from memory.
# No reads for chromosome chrUn_KI270588v1, skipping it.
# Removing chromosome chrUn_KI270588v1 from memory.
# No reads for chromosome chrUn_KI270593v1, skipping it.
# Removing chromosome chrUn_KI270593v1 from memory.
# No reads for chromosome chrUn_KI270591v1, skipping it.
# Removing chromosome chrUn_KI270591v1 from memory.
# No reads for chromosome chrUn_KI270330v1, skipping it.
# Removing chromosome chrUn_KI270330v1 from memory.
# No reads for chromosome chrUn_KI270329v1, skipping it.
# Removing chromosome chrUn_KI270329v1 from memory.
# No reads for chromosome chrUn_KI270334v1, skipping it.
# Removing chromosome chrUn_KI270334v1 from memory.
# No reads for chromosome chrUn_KI270333v1, skipping it.
# Removing chromosome chrUn_KI270333v1 from memory.
# No reads for chromosome chrUn_KI270335v1, skipping it.
# Removing chromosome chrUn_KI270335v1 from memory.
# No reads for chromosome chrUn_KI270338v1, skipping it.
# Removing chromosome chrUn_KI270338v1 from memory.
# No reads for chromosome chrUn_KI270340v1, skipping it.
# Removing chromosome chrUn_KI270340v1 from memory.
# No reads for chromosome chrUn_KI270336v1, skipping it.
# Removing chromosome chrUn_KI270336v1 from memory.
# No reads for chromosome chrUn_KI270337v1, skipping it.
# Removing chromosome chrUn_KI270337v1 from memory.
# No reads for chromosome chrUn_KI270363v1, skipping it.
# Removing chromosome chrUn_KI270363v1 from memory.
# No reads for chromosome chrUn_KI270364v1, skipping it.
# Removing chromosome chrUn_KI270364v1 from memory.
# No reads for chromosome chrUn_KI270362v1, skipping it.
# Removing chromosome chrUn_KI270362v1 from memory.
# No reads for chromosome chrUn_KI270366v1, skipping it.
# Removing chromosome chrUn_KI270366v1 from memory.
# No reads for chromosome chrUn_KI270378v1, skipping it.
# Removing chromosome chrUn_KI270378v1 from memory.
# No reads for chromosome chrUn_KI270379v1, skipping it.
# Removing chromosome chrUn_KI270379v1 from memory.
# No reads for chromosome chrUn_KI270389v1, skipping it.
# Removing chromosome chrUn_KI270389v1 from memory.
# No reads for chromosome chrUn_KI270390v1, skipping it.
# Removing chromosome chrUn_KI270390v1 from memory.
# No reads for chromosome chrUn_KI270387v1, skipping it.
# Removing chromosome chrUn_KI270387v1 from memory.
# No reads for chromosome chrUn_KI270395v1, skipping it.
# Removing chromosome chrUn_KI270395v1 from memory.
# No reads for chromosome chrUn_KI270396v1, skipping it.
# Removing chromosome chrUn_KI270396v1 from memory.
# No reads for chromosome chrUn_KI270388v1, skipping it.
# Removing chromosome chrUn_KI270388v1 from memory.
# No reads for chromosome chrUn_KI270394v1, skipping it.
# Removing chromosome chrUn_KI270394v1 from memory.
# No reads for chromosome chrUn_KI270386v1, skipping it.
# Removing chromosome chrUn_KI270386v1 from memory.
# No reads for chromosome chrUn_KI270391v1, skipping it.
# Removing chromosome chrUn_KI270391v1 from memory.
# No reads for chromosome chrUn_KI270383v1, skipping it.
# Removing chromosome chrUn_KI270383v1 from memory.
# No reads for chromosome chrUn_KI270393v1, skipping it.
# Removing chromosome chrUn_KI270393v1 from memory.
# No reads for chromosome chrUn_KI270384v1, skipping it.
# Removing chromosome chrUn_KI270384v1 from memory.
# No reads for chromosome chrUn_KI270392v1, skipping it.
# Removing chromosome chrUn_KI270392v1 from memory.
# No reads for chromosome chrUn_KI270381v1, skipping it.
# Removing chromosome chrUn_KI270381v1 from memory.
# No reads for chromosome chrUn_KI270385v1, skipping it.
# Removing chromosome chrUn_KI270385v1 from memory.
# No reads for chromosome chrUn_KI270382v1, skipping it.
# Removing chromosome chrUn_KI270382v1 from memory.
# No reads for chromosome chrUn_KI270376v1, skipping it.
# Removing chromosome chrUn_KI270376v1 from memory.
# No reads for chromosome chrUn_KI270374v1, skipping it.
# Removing chromosome chrUn_KI270374v1 from memory.
# No reads for chromosome chrUn_KI270372v1, skipping it.
# Removing chromosome chrUn_KI270372v1 from memory.
# No reads for chromosome chrUn_KI270373v1, skipping it.
# Removing chromosome chrUn_KI270373v1 from memory.
# No reads for chromosome chrUn_KI270375v1, skipping it.
# Removing chromosome chrUn_KI270375v1 from memory.
# No reads for chromosome chrUn_KI270371v1, skipping it.
# Removing chromosome chrUn_KI270371v1 from memory.
# No reads for chromosome chrUn_KI270448v1, skipping it.
# Removing chromosome chrUn_KI270448v1 from memory.
# No reads for chromosome chrUn_KI270521v1, skipping it.
# Removing chromosome chrUn_KI270521v1 from memory.
# No reads for chromosome chrUn_GL000195v1, skipping it.
# Removing chromosome chrUn_GL000195v1 from memory.
# No reads for chromosome chrUn_GL000219v1, skipping it.
# Removing chromosome chrUn_GL000219v1 from memory.
# No reads for chromosome chrUn_GL000220v1, skipping it.
# Removing chromosome chrUn_GL000220v1 from memory.
# No reads for chromosome chrUn_GL000224v1, skipping it.
# Removing chromosome chrUn_GL000224v1 from memory.
# No reads for chromosome chrUn_KI270741v1, skipping it.
# Removing chromosome chrUn_KI270741v1 from memory.
# No reads for chromosome chrUn_GL000226v1, skipping it.
# Removing chromosome chrUn_GL000226v1 from memory.
# No reads for chromosome chrUn_GL000213v1, skipping it.
# Removing chromosome chrUn_GL000213v1 from memory.
# No reads for chromosome chrUn_KI270743v1, skipping it.
# Removing chromosome chrUn_KI270743v1 from memory.
# No reads for chromosome chrUn_KI270744v1, skipping it.
# Removing chromosome chrUn_KI270744v1 from memory.
# No reads for chromosome chrUn_KI270745v1, skipping it.
# Removing chromosome chrUn_KI270745v1 from memory.
# No reads for chromosome chrUn_KI270746v1, skipping it.
# Removing chromosome chrUn_KI270746v1 from memory.
# No reads for chromosome chrUn_KI270747v1, skipping it.
# Removing chromosome chrUn_KI270747v1 from memory.
# No reads for chromosome chrUn_KI270748v1, skipping it.
# Removing chromosome chrUn_KI270748v1 from memory.
# No reads for chromosome chrUn_KI270749v1, skipping it.
# Removing chromosome chrUn_KI270749v1 from memory.
# No reads for chromosome chrUn_KI270750v1, skipping it.
# Removing chromosome chrUn_KI270750v1 from memory.
# No reads for chromosome chrUn_KI270751v1, skipping it.
# Removing chromosome chrUn_KI270751v1 from memory.
# No reads for chromosome chrUn_KI270752v1, skipping it.
# Removing chromosome chrUn_KI270752v1 from memory.
# No reads for chromosome chrUn_KI270753v1, skipping it.
# Removing chromosome chrUn_KI270753v1 from memory.
# No reads for chromosome chrUn_KI270754v1, skipping it.
# Removing chromosome chrUn_KI270754v1 from memory.
# No reads for chromosome chrUn_KI270755v1, skipping it.
# Removing chromosome chrUn_KI270755v1 from memory.
# No reads for chromosome chrUn_KI270756v1, skipping it.
# Removing chromosome chrUn_KI270756v1 from memory.
# No reads for chromosome chrUn_KI270757v1, skipping it.
# Removing chromosome chrUn_KI270757v1 from memory.
# No reads for chromosome chrUn_GL000214v1, skipping it.
# Removing chromosome chrUn_GL000214v1 from memory.
# No reads for chromosome chrUn_KI270742v1, skipping it.
# Removing chromosome chrUn_KI270742v1 from memory.
# No reads for chromosome chrUn_GL000216v2, skipping it.
# Removing chromosome chrUn_GL000216v2 from memory.
# No reads for chromosome chrUn_GL000218v1, skipping it.
# Removing chromosome chrUn_GL000218v1 from memory.
# No reads for chromosome chrEBV, skipping it.
# Removing chromosome chrEBV from memory.
#
# Note: for this conversion, the -G (GATK) compatibility option was used; it's possible that this format is not compatible with other VCF-reading software. Also note that GATK requires genotypes to be 0/0, 0/1 or 1/1 instead of undefined, like ./1 or . ('not detected'). However, since pindel cannot yet genotype events (distinguish between 0/1 and 1/1) all events are called as 0/0 (not found) or 0/1, even while some may very well be homozygous alternative (1/1).

# %%
#The get_results command returns a dictionary of 'LOC INDEL INFO' => COUNT for each indel found. 
#For example, the key/value pair {'12345 D 1' : 5}
#   means that a 1bp deletion was found at location 12345 with a coverage of 5 reads.
#We'll print that dictionary of results out here:
test_indels = pindelCaller.get_results(test_sample_sim_bam,test_sample_control_bam)
print(test_indels)
# Out:
# ({'835718 D 2': 2, '836294 D 2': 5, '836509 D 1': 2, '836538 D 1': 22}, {'835718 D 2': <mutation.Mutation object at 0x147e55d06d00>, '836294 D 2': <mutation.Mutation object at 0x148202171df0>, '836509 D 1': <mutation.Mutation object at 0x147e558d4b50>, '836538 D 1': <mutation.Mutation object at 0x147e558d4d90>})
# [W::bcf_hdr_check_sanity] PL should be declared as Number=G
# [W::vcf_parse] Contig 'chr11' is not defined in the header. (Quick workaround: index the file with tabix.)

# %% [markdown]
# Now that we have shown the basic functionality of the caller class, we can run all of the callers on each of the simulated samples, and aggregate the results.
# ## Run each caller on all of the sample pairs

# %%
for caller in callers:
    caller_commands = []
    caller_name = caller.get_name()
    for name, simulated_bam, simulated_control in samples:
        this_command, is_finished = caller.run_caller(simulated_bam,simulated_control)
        if not is_finished:
            caller_commands.append(this_command)
    if len(caller_commands) > 0:
        print ("got " + str(len(caller_commands)) + " commands to run " + caller_name)
        for command in caller_commands:
            print("running command " + command)
            call(command,shell=True)
            print("Finished")
    else:
        print('Finished running ' + caller_name + ' commands')
# Out:
# Finished running Pindel commands
# got 2 commands to run Lofreq
# running command conda run -n kc_lofreq bash -c " rm -f /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq* && lofreq indelqual --dindel -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.lofreq_indelqual.sim.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam && samtools index /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.lofreq_indelqual.sim.bam && lofreq indelqual --dindel -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.lofreq_indelqual.ctl.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam && samtools index /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.lofreq_indelqual.ctl.bam && lofreq somatic -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -t /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.lofreq_indelqual.sim.bam -n /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.lofreq_indelqual.ctl.bam --min-cov 0 --call-indels -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq_ && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.lofreq/lofreq.finished"
# /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_lofreq/bin/lofreq2_somatic.py:784: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   LOG.warn("No dbsnp file given. Using dbsnp is highly recommended"
# WARNING [2025-07-22 18:10:20,517]: No dbsnp file given. Using dbsnp is highly recommended when dealing with human data.
# /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_lofreq/bin/lofreq2_somatic.py:513: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   LOG.warn("uniq stderr: %s" % l.decode())
# WARNING [2025-07-22 18:10:32,161]: uniq stderr: WARNING(lofreq_uniq.c|main_uniq): Didn't find any variants in input
# Finished
# running command conda run -n kc_lofreq bash -c " rm -f /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq* && lofreq indelqual --dindel -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.lofreq_indelqual.sim.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam && samtools index /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.lofreq_indelqual.sim.bam && lofreq indelqual --dindel -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.lofreq_indelqual.ctl.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam && samtools index /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.lofreq_indelqual.ctl.bam && lofreq somatic -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -t /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.lofreq_indelqual.sim.bam -n /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.lofreq_indelqual.ctl.bam --min-cov 0 --call-indels -o /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq_ && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.lofreq/lofreq.finished"
# /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_lofreq/bin/lofreq2_somatic.py:784: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   LOG.warn("No dbsnp file given. Using dbsnp is highly recommended"
# WARNING [2025-07-22 18:10:52,620]: No dbsnp file given. Using dbsnp is highly recommended when dealing with human data.
# /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_lofreq/bin/lofreq2_somatic.py:513: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   LOG.warn("uniq stderr: %s" % l.decode())
# WARNING [2025-07-22 18:11:09,226]: uniq stderr: WARNING(lofreq_uniq.c|main_uniq): Didn't find any variants in input
#
# /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_lofreq/bin/lofreq2_somatic.py:513: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   LOG.warn("uniq stderr: %s" % l.decode())
# WARNING [2025-07-22 18:11:09,231]: uniq stderr: WARNING(lofreq_uniq.c|main_uniq): Didn't find any variants in input
# Finished
# got 2 commands to run VarDict
# running command conda run -n kc_vardict bash -c " vardict -f 0.0001 -G genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -b '/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam|/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam'  -R chr11:835197-837397 -r 1 | testsomatic.R | var2vcf_paired.pl -A -N 'simulated|simulatedCtl' -f 0.0001 > /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.vardict/vardict.vcf && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.vardict/vardict.finished"
# Finished
# running command conda run -n kc_vardict bash -c " vardict -f 0.0001 -G genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -b '/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam|/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam'  -R chr11:835197-837397 -r 1 | testsomatic.R | var2vcf_paired.pl -A -N 'simulated|simulatedCtl' -f 0.0001 > /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.vardict/vardict.vcf && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.vardict/vardict.finished"
# Finished
# got 2 commands to run SomaticSniper
# running command conda run -n kc_somaticSniper bash -c "bam-somaticsniper -N 100 -F vcf -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.somaticSniper/somaticSniper.vcf && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.somaticSniper/somaticSniper.finished"
# Preparing to snipe some somatics
# Using prior probabilities
# Normal bam is /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam
# Tumor bam is /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam
# Finished
# running command conda run -n kc_somaticSniper bash -c "bam-somaticsniper -N 100 -F vcf -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.somaticSniper/somaticSniper.vcf && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.somaticSniper/somaticSniper.finished"
# Preparing to snipe some somatics
# Using prior probabilities
# Normal bam is /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam
# Tumor bam is /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam
# Finished
# got 2 commands to run Varscan
# running command conda run -n kc_varscan bash -c " samtools mpileup -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam > /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.sim.pileup  && samtools mpileup -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam > /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.ctl.pileup  && varscan somatic /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.ctl.pileup /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.sim.pileup /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan --output-vcf --min-coverage 1 --min-coverage-normal 1 --min-coverage-tumor 1 --somatic-p-value 1  && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.finished"
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# Normal Pileup: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.ctl.pileup
# Tumor Pileup: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.varscan/varscan.sim.pileup
# NOTICE: While dual input files are still supported, using a single mpileup file (normal-tumor) with the --mpileup 1 setting is strongly recommended.
# Min coverage:	1x for Normal, 1x for Tumor
# Min reads2:	2
# Min strands2:	1
# Min var freq:	0.2
# Min freq for hom:	0.75
# Normal purity:	1.0
# Tumor purity:	1.0
# Min avg qual:	15
# P-value thresh:	0.99
# Somatic p-value:	1.0
# 10275 positions in tumor
# 10275 positions shared in normal
# 10243 had sufficient coverage for comparison
# 10225 were called Reference
# 0 were mixed SNP-indel calls and filtered
# 18 were called Germline
# 0 were called LOH
# 0 were called Somatic
# 0 were called Unknown
# 0 were called Variant
# Finished
# running command conda run -n kc_varscan bash -c " samtools mpileup -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam > /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.sim.pileup  && samtools mpileup -f genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam > /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.ctl.pileup  && varscan somatic /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.ctl.pileup /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.sim.pileup /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan --output-vcf --min-coverage 1 --min-coverage-normal 1 --min-coverage-tumor 1 --somatic-p-value 1  && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.finished"
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# Normal Pileup: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.ctl.pileup
# Tumor Pileup: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.varscan/varscan.sim.pileup
# NOTICE: While dual input files are still supported, using a single mpileup file (normal-tumor) with the --mpileup 1 setting is strongly recommended.
# Min coverage:	1x for Normal, 1x for Tumor
# Min reads2:	2
# Min strands2:	1
# Min var freq:	0.2
# Min freq for hom:	0.75
# Normal purity:	1.0
# Tumor purity:	1.0
# Min avg qual:	15
# P-value thresh:	0.99
# Somatic p-value:	1.0
# 10269 positions in tumor
# 10269 positions shared in normal
# 10224 had sufficient coverage for comparison
# 10206 were called Reference
# 0 were mixed SNP-indel calls and filtered
# 18 were called Germline
# 0 were called LOH
# 0 were called Somatic
# 0 were called Unknown
# 0 were called Variant
# Finished
# got 2 commands to run Mutect
# running command conda run -n kc_gatk4 bash -c "gatk Mutect2 -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam -normal simulatedCtl -O /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.unfiltered.vcf -L chr11:835197-837397 &&  gatk FilterMutectCalls -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -V /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.unfiltered.vcf -O  /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.filtered.vcf && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.finished"
# Tool returned:
# SUCCESS
#
# Finished
# running command conda run -n kc_gatk4 bash -c "gatk Mutect2 -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam -normal simulatedCtl -O /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.unfiltered.vcf -L chr11:835197-837397 &&  gatk FilterMutectCalls -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -V /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.unfiltered.vcf -O  /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.filtered.vcf && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.finished"
# Using GATK jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar Mutect2 -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam -normal simulatedCtl -O /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.unfiltered.vcf -L chr11:835197-837397
# 18:12:06.612 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 18:12:06.641 INFO  Mutect2 - ------------------------------------------------------------
# 18:12:06.644 INFO  Mutect2 - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 18:12:06.644 INFO  Mutect2 - For support and documentation go to https://software.broadinstitute.org/gatk/
# 18:12:06.644 INFO  Mutect2 - Executing as u0351481@notchpeak30 on Linux v4.18.0-553.44.1.el8_10.x86_64 amd64
# 18:12:06.644 INFO  Mutect2 - Java runtime: OpenJDK 64-Bit Server VM v17.0.3-internal+0-adhoc..src
# 18:12:06.644 INFO  Mutect2 - Start Date/Time: July 22, 2025 at 6:12:06 PM MDT
# 18:12:06.644 INFO  Mutect2 - ------------------------------------------------------------
# 18:12:06.644 INFO  Mutect2 - ------------------------------------------------------------
# 18:12:06.645 INFO  Mutect2 - HTSJDK Version: 3.0.5
# 18:12:06.645 INFO  Mutect2 - Picard Version: 3.0.0
# 18:12:06.645 INFO  Mutect2 - Built for Spark Version: 3.3.1
# 18:12:06.645 INFO  Mutect2 - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 18:12:06.645 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 18:12:06.646 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 18:12:06.646 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 18:12:06.646 INFO  Mutect2 - Deflater: IntelDeflater
# 18:12:06.646 INFO  Mutect2 - Inflater: IntelInflater
# 18:12:06.646 INFO  Mutect2 - GCS max retries/reopens: 20
# 18:12:06.646 INFO  Mutect2 - Requester pays: disabled
# 18:12:06.646 INFO  Mutect2 - Initializing engine
# 18:12:06.791 INFO  IntervalArgumentCollection - Processing 2201 bp from intervals
# 18:12:06.795 INFO  Mutect2 - Done initializing engine
# 18:12:06.811 INFO  NativeLibraryLoader - Loading libgkl_utils.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.so
# 18:12:06.831 INFO  NativeLibraryLoader - Loading libgkl_pairhmm_omp.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm_omp.so
# 18:12:06.855 INFO  IntelPairHmm - Using CPU-supported AVX-512 instructions
# 18:12:06.855 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 18:12:06.855 INFO  IntelPairHmm - Available threads: 112
# 18:12:06.855 INFO  IntelPairHmm - Requested threads: 4
# 18:12:06.855 INFO  PairHMM - Using the OpenMP multi-threaded AVX-accelerated native PairHMM implementation
# 18:12:06.886 INFO  ProgressMeter - Starting traversal
# 18:12:06.886 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 18:12:07.504 INFO  Mutect2 - 12 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappingQualityNotZeroReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonChimericOriginalAlignmentReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: ReadLengthReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 12 total reads filtered out of 1066 reads processed
# 18:12:07.506 INFO  ProgressMeter -         chr11:837240              0.0                    10            972.4
# 18:12:07.506 INFO  ProgressMeter - Traversal complete. Processed 10 total regions in 0.0 minutes.
# 18:12:07.514 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.001173157
# 18:12:07.514 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 0.007923324
# 18:12:07.514 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 0.06 sec
# 18:12:07.515 INFO  Mutect2 - Shutting down engine
# [July 22, 2025 at 6:12:07 PM MDT] org.broadinstitute.hellbender.tools.walkers.mutect.Mutect2 done. Elapsed time: 0.02 minutes.
# Runtime.totalMemory()=285212672
# Using GATK jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar FilterMutectCalls -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -V /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.unfiltered.vcf -O /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.filtered.vcf
# 18:12:09.219 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 18:12:09.248 INFO  FilterMutectCalls - ------------------------------------------------------------
# 18:12:09.250 INFO  FilterMutectCalls - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 18:12:09.250 INFO  FilterMutectCalls - For support and documentation go to https://software.broadinstitute.org/gatk/
# 18:12:09.251 INFO  FilterMutectCalls - Executing as u0351481@notchpeak30 on Linux v4.18.0-553.44.1.el8_10.x86_64 amd64
# 18:12:09.251 INFO  FilterMutectCalls - Java runtime: OpenJDK 64-Bit Server VM v17.0.3-internal+0-adhoc..src
# 18:12:09.251 INFO  FilterMutectCalls - Start Date/Time: July 22, 2025 at 6:12:09 PM MDT
# 18:12:09.251 INFO  FilterMutectCalls - ------------------------------------------------------------
# 18:12:09.251 INFO  FilterMutectCalls - ------------------------------------------------------------
# 18:12:09.252 INFO  FilterMutectCalls - HTSJDK Version: 3.0.5
# 18:12:09.252 INFO  FilterMutectCalls - Picard Version: 3.0.0
# 18:12:09.252 INFO  FilterMutectCalls - Built for Spark Version: 3.3.1
# 18:12:09.252 INFO  FilterMutectCalls - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 18:12:09.252 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 18:12:09.252 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 18:12:09.253 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 18:12:09.253 INFO  FilterMutectCalls - Deflater: IntelDeflater
# 18:12:09.253 INFO  FilterMutectCalls - Inflater: IntelInflater
# 18:12:09.253 INFO  FilterMutectCalls - GCS max retries/reopens: 20
# 18:12:09.253 INFO  FilterMutectCalls - Requester pays: disabled
# 18:12:09.253 INFO  FilterMutectCalls - Initializing engine
# 18:12:09.410 INFO  FeatureManager - Using codec VCFCodec to read file file:///uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.mutect/mutect.unfiltered.vcf
# 18:12:09.436 INFO  FilterMutectCalls - Done initializing engine
# 18:12:09.481 INFO  ProgressMeter - Starting traversal
# 18:12:09.482 INFO  ProgressMeter -        Current Locus  Elapsed Minutes    Variants Processed  Variants/Minute
# 18:12:09.482 INFO  FilterMutectCalls - Starting pass 0 through the variants
# 18:12:09.547 INFO  FilterMutectCalls - Finished pass 0 through the variants
# 18:12:09.593 INFO  FilterMutectCalls - Starting pass 1 through the variants
# 18:12:09.597 INFO  FilterMutectCalls - Finished pass 1 through the variants
# 18:12:09.600 INFO  FilterMutectCalls - Starting pass 2 through the variants
# 18:12:09.604 INFO  FilterMutectCalls - Finished pass 2 through the variants
# 18:12:09.604 INFO  FilterMutectCalls - Starting pass 3 through the variants
# 18:12:09.652 INFO  FilterMutectCalls - Finished pass 3 through the variants
# 18:12:09.683 INFO  FilterMutectCalls - No variants filtered by: AllowAllVariantsVariantFilter
# 18:12:09.683 INFO  FilterMutectCalls - 0 read(s) filtered by: AllowAllReadsReadFilter
#
# 18:12:09.683 INFO  ProgressMeter -             unmapped              0.0                     4           1194.0
# 18:12:09.683 INFO  ProgressMeter - Traversal complete. Processed 4 total variants in 0.0 minutes.
# 18:12:09.687 INFO  FilterMutectCalls - Shutting down engine
# [July 22, 2025 at 6:12:09 PM MDT] org.broadinstitute.hellbender.tools.walkers.mutect.filtering.FilterMutectCalls done. Elapsed time: 0.01 minutes.
# Runtime.totalMemory()=285212672
# Tool returned:
# SUCCESS
#
# Finished
# got 2 commands to run Strelka
# running command conda run -n kc_strelka2 bash -c " rm -rf /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka && rm -rf /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta && configManta.py  --normalBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam --tumorBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam --referenceFasta genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa --runDir /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta && /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta/runWorkflow.py -m local -j 20 && configureStrelkaSomaticWorkflow.py  --normalBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.ctl.bam --tumorBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.bam --referenceFasta genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa --indelCandidates /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta/results/variants/candidateSmallIndels.vcf.gz --runDir /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka && /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/runWorkflow.py -m local -j 20 && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/strelka.finished"
# Using GATK jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar Mutect2 -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam -I /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam -normal simulatedCtl -O /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.unfiltered.vcf -L chr11:835197-837397
# 18:12:12.346 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 18:12:12.374 INFO  Mutect2 - ------------------------------------------------------------
# 18:12:12.377 INFO  Mutect2 - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 18:12:12.377 INFO  Mutect2 - For support and documentation go to https://software.broadinstitute.org/gatk/
# 18:12:12.377 INFO  Mutect2 - Executing as u0351481@notchpeak30 on Linux v4.18.0-553.44.1.el8_10.x86_64 amd64
# 18:12:12.377 INFO  Mutect2 - Java runtime: OpenJDK 64-Bit Server VM v17.0.3-internal+0-adhoc..src
# 18:12:12.377 INFO  Mutect2 - Start Date/Time: July 22, 2025 at 6:12:12 PM MDT
# 18:12:12.377 INFO  Mutect2 - ------------------------------------------------------------
# 18:12:12.377 INFO  Mutect2 - ------------------------------------------------------------
# 18:12:12.378 INFO  Mutect2 - HTSJDK Version: 3.0.5
# 18:12:12.378 INFO  Mutect2 - Picard Version: 3.0.0
# 18:12:12.378 INFO  Mutect2 - Built for Spark Version: 3.3.1
# 18:12:12.378 INFO  Mutect2 - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 18:12:12.378 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 18:12:12.378 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 18:12:12.379 INFO  Mutect2 - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 18:12:12.379 INFO  Mutect2 - Deflater: IntelDeflater
# 18:12:12.379 INFO  Mutect2 - Inflater: IntelInflater
# 18:12:12.379 INFO  Mutect2 - GCS max retries/reopens: 20
# 18:12:12.379 INFO  Mutect2 - Requester pays: disabled
# 18:12:12.379 INFO  Mutect2 - Initializing engine
# 18:12:12.525 INFO  IntervalArgumentCollection - Processing 2201 bp from intervals
# 18:12:12.529 INFO  Mutect2 - Done initializing engine
# 18:12:12.545 INFO  NativeLibraryLoader - Loading libgkl_utils.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.so
# 18:12:12.546 INFO  NativeLibraryLoader - Loading libgkl_pairhmm_omp.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm_omp.so
# 18:12:12.570 INFO  IntelPairHmm - Using CPU-supported AVX-512 instructions
# 18:12:12.570 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 18:12:12.570 INFO  IntelPairHmm - Available threads: 112
# 18:12:12.570 INFO  IntelPairHmm - Requested threads: 4
# 18:12:12.570 INFO  PairHMM - Using the OpenMP multi-threaded AVX-accelerated native PairHMM implementation
# 18:12:12.599 INFO  ProgressMeter - Starting traversal
# 18:12:12.599 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 18:12:13.285 INFO  Mutect2 - 6 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappingQualityNotZeroReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonChimericOriginalAlignmentReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: ReadLengthReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 6 total reads filtered out of 1126 reads processed
# 18:12:13.286 INFO  ProgressMeter -         chr11:837243              0.0                    10            874.6
# 18:12:13.286 INFO  ProgressMeter - Traversal complete. Processed 10 total regions in 0.0 minutes.
# 18:12:13.294 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.001127828
# 18:12:13.294 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 0.009999762
# 18:12:13.294 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 0.11 sec
# 18:12:13.295 INFO  Mutect2 - Shutting down engine
# [July 22, 2025 at 6:12:13 PM MDT] org.broadinstitute.hellbender.tools.walkers.mutect.Mutect2 done. Elapsed time: 0.02 minutes.
# Runtime.totalMemory()=285212672
# Using GATK jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar FilterMutectCalls -R genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa -V /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.unfiltered.vcf -O /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.filtered.vcf
# 18:12:14.984 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/envs/kc_gatk4/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# 18:12:15.109 INFO  FilterMutectCalls - ------------------------------------------------------------
# 18:12:15.111 INFO  FilterMutectCalls - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 18:12:15.111 INFO  FilterMutectCalls - For support and documentation go to https://software.broadinstitute.org/gatk/
# 18:12:15.112 INFO  FilterMutectCalls - Executing as u0351481@notchpeak30 on Linux v4.18.0-553.44.1.el8_10.x86_64 amd64
# 18:12:15.112 INFO  FilterMutectCalls - Java runtime: OpenJDK 64-Bit Server VM v17.0.3-internal+0-adhoc..src
# 18:12:15.112 INFO  FilterMutectCalls - Start Date/Time: July 22, 2025 at 6:12:14 PM MDT
# 18:12:15.112 INFO  FilterMutectCalls - ------------------------------------------------------------
# 18:12:15.112 INFO  FilterMutectCalls - ------------------------------------------------------------
# 18:12:15.113 INFO  FilterMutectCalls - HTSJDK Version: 3.0.5
# 18:12:15.113 INFO  FilterMutectCalls - Picard Version: 3.0.0
# 18:12:15.113 INFO  FilterMutectCalls - Built for Spark Version: 3.3.1
# 18:12:15.113 INFO  FilterMutectCalls - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 18:12:15.113 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 18:12:15.114 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 18:12:15.114 INFO  FilterMutectCalls - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 18:12:15.114 INFO  FilterMutectCalls - Deflater: IntelDeflater
# 18:12:15.114 INFO  FilterMutectCalls - Inflater: IntelInflater
# 18:12:15.114 INFO  FilterMutectCalls - GCS max retries/reopens: 20
# 18:12:15.114 INFO  FilterMutectCalls - Requester pays: disabled
# 18:12:15.115 INFO  FilterMutectCalls - Initializing engine
# 18:12:15.239 INFO  FeatureManager - Using codec VCFCodec to read file file:///uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.mutect/mutect.unfiltered.vcf
# 18:12:15.265 INFO  FilterMutectCalls - Done initializing engine
# 18:12:15.310 INFO  ProgressMeter - Starting traversal
# 18:12:15.311 INFO  ProgressMeter -        Current Locus  Elapsed Minutes    Variants Processed  Variants/Minute
# 18:12:15.311 INFO  FilterMutectCalls - Starting pass 0 through the variants
# 18:12:15.364 INFO  FilterMutectCalls - Finished pass 0 through the variants
# 18:12:15.392 INFO  FilterMutectCalls - Starting pass 1 through the variants
# 18:12:15.395 INFO  FilterMutectCalls - Finished pass 1 through the variants
# 18:12:15.397 INFO  FilterMutectCalls - Starting pass 2 through the variants
# 18:12:15.399 INFO  FilterMutectCalls - Finished pass 2 through the variants
# 18:12:15.400 INFO  FilterMutectCalls - Starting pass 3 through the variants
# 18:12:15.413 INFO  FilterMutectCalls - Finished pass 3 through the variants
# 18:12:15.420 INFO  FilterMutectCalls - No variants filtered by: AllowAllVariantsVariantFilter
# 18:12:15.420 INFO  FilterMutectCalls - 0 read(s) filtered by: AllowAllReadsReadFilter
#
# 18:12:15.420 INFO  ProgressMeter -             unmapped              0.0                     4           2201.8
# 18:12:15.421 INFO  ProgressMeter - Traversal complete. Processed 4 total variants in 0.0 minutes.
# 18:12:15.423 INFO  FilterMutectCalls - Shutting down engine
# [July 22, 2025 at 6:12:15 PM MDT] org.broadinstitute.hellbender.tools.walkers.mutect.filtering.FilterMutectCalls done. Elapsed time: 0.01 minutes.
# Runtime.totalMemory()=285212672
# Successfully created workflow run script.
# To execute the workflow, run the following script and set appropriate options:
#
# /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta/runWorkflow.py
#
# Successfully created workflow run script.
# To execute the workflow, run the following script and set appropriate options:
#
# /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/runWorkflow.py
#
# Finished
# running command conda run -n kc_strelka2 bash -c " rm -rf /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka && rm -rf /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka/manta && configManta.py  --normalBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam --tumorBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam --referenceFasta genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa --runDir /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka/manta && /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka/manta/runWorkflow.py -m local -j 20 && configureStrelkaSomaticWorkflow.py  --normalBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.ctl.bam --tumorBam /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.bam --referenceFasta genomes/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa --indelCandidates /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka/manta/results/variants/candidateSmallIndels.vcf.gz --runDir /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka && /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka/runWorkflow.py -m local -j 20 && touch /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD2_r0.caller.strelka/strelka.finished"
# [2025-07-23T00:12:16.817620Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] Initiating pyFlow run
# [2025-07-23T00:12:16.817807Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] pyFlowClientWorkflowClass: MantaWorkflow
# [2025-07-23T00:12:16.817821Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] pyFlowVersion: 1.1.20
# [2025-07-23T00:12:16.817831Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] pythonVersion: 2.7.18.final.0
# [2025-07-23T00:12:16.817839Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] WorkingDir: '/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs'
# [2025-07-23T00:12:16.817847Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] ProcessCmdLine: '/uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta/runWorkflow.py -m local -j 20'
# [2025-07-23T00:12:16.817856Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] mode: local
# [2025-07-23T00:12:16.817866Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] nCores: 20
# [2025-07-23T00:12:16.817874Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] memMb: 515106
# [2025-07-23T00:12:16.817883Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] dataDir: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20230508_uwgs/analysis/mutsuite/mutsuite/docs/simSettings.txt.output/sim_d30_p5.0_q0_sD1_r0.caller.strelka/manta/workspace/pyflow.data
# [2025-07-23T00:12:16.817892Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] isDryRun: False
# [2025-07-23T00:12:16.817900Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] isContinue: False
# [2025-07-23T00:12:16.817909Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] isForceContinue: True
# [2025-07-23T00:12:16.817918Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] [RunParameters] mailTo: ''
# [2025-07-23T00:12:16.818277Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [TaskRunner:masterWorkflow] Starting task specification for master workflow
# [2025-07-23T00:12:16.818370Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [MantaWorkflow] Initiating Manta workflow version: 1.6.0
# [2025-07-23T00:12:16.818651Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] Adding command task 'getAlignmentStats_makeTmpDir' to master workflow
# [2025-07-23T00:12:16.818980Z] [notchpeak30.int.chpc.utah.edu] [2018175_1] [WorkflowRunner] Adding command task 'getAlignmentStats_generateStats_000' to master workflow
# ...
# [2025-07-23T00:13:16.496799Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_014_chr15_0004] Task initiated on local node
# [2025-07-23T00:13:16.500624Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_003_chr4_0013] Task initiated on local node
# [2025-07-23T00:13:16.509576Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_002_chr3_0004' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.512691Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_002_chr3_0004' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.512999Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_006_chr7_0010' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.518466Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_002_chr3_0004] Task initiated on local node
# [2025-07-23T00:13:16.518671Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_001_chr2_0009' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.518759Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_175_chrUn_KI270743v1_0000' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.518816Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_012_chr13_0007' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.521692Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_001_chr2_0005' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.521747Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_013_chr14_0000' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.550421Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+callGenomeSegment_chromId_183_chrUn_KI270751v1_0000_to_chromId_184_chrUn_KI270752v1_0000] Task initiated on local node
# [2025-07-23T00:13:16.555458Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_014_chr15_0004' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.558473Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_003_chr4_0013' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.575870Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_000_chr1_0008' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.575933Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_174_chrUn_GL000213v1_0000' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.578468Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_174_chrUn_GL000213v1_0000' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.578827Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_000_chr1_0008' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.579031Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_002_chr3_0004' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.583898Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_174_chrUn_GL000213v1_0000] Task initiated on local node
# [2025-07-23T00:13:16.585787Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_000_chr1_0008] Task initiated on local node
# [2025-07-23T00:13:16.699686Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_174_chrUn_GL000213v1_0000' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.699773Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_000_chr1_0008' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.699817Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_012_chr13_0004' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.699852Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_014_chr15_0001' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.699996Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_183_chrUn_KI270751v1_0000_to_chromId_184_chrUn_KI270752v1_0000' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.702275Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_183_chrUn_KI270751v1_0000_to_chromId_184_chrUn_KI270752v1_0000' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.702578Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_012_chr13_0004' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.702813Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_014_chr15_0001' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.708104Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_183_chrUn_KI270751v1_0000_to_chromId_184_chrUn_KI270752v1_0000] Task initiated on local node
# [2025-07-23T00:13:16.708602Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_012_chr13_0004] Task initiated on local node
# [2025-07-23T00:13:16.709953Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_014_chr15_0001] Task initiated on local node
# [2025-07-23T00:13:16.720224Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_001_chr2_0003' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.722781Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_001_chr2_0003' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.725549Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_003_chr4_0014' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.727420Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_001_chr2_0003] Task initiated on local node
# [2025-07-23T00:13:16.728534Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_003_chr4_0014' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.760091Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_183_chrUn_KI270751v1_0000_to_chromId_184_chrUn_KI270752v1_0000' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.760147Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_012_chr13_0004' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.760188Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_014_chr15_0001' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.765384Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_003_chr4_0014] Task initiated on local node
# [2025-07-23T00:13:16.777832Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_001_chr2_0003' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.843601Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_003_chr4_0014' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.843669Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_012_chr13_0008' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.843707Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_014_chr15_0006' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.843745Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_009_chr10_0010' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.845986Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_009_chr10_0010' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.846206Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_012_chr13_0008' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.846460Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_014_chr15_0006' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.849755Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+callGenomeSegment_chromId_008_chr9_0005' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.851882Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+compressSegmentOutput_chromId_008_chr9_0005' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.861710Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_009_chr10_0010] Task initiated on local node
# [2025-07-23T00:13:16.862564Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_012_chr13_0008] Task initiated on local node
# [2025-07-23T00:13:16.870672Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_008_chr9_0005] Task initiated on local node
# [2025-07-23T00:13:16.926435Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+compressSegmentOutput_chromId_014_chr15_0006] Task initiated on local node
# [2025-07-23T00:13:16.966009Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_009_chr10_0010' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.966071Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_012_chr13_0008' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.966109Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_014_chr15_0006' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.966152Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+compressSegmentOutput_chromId_008_chr9_0005' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.967961Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+completedAllGenomeSegments' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.968128Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+SNV_concat_vcf' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.968413Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+mergeRunStats' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.968636Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+Indel_concat_vcf' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:16.980753Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+SNV_concat_vcf] Task initiated on local node
# [2025-07-23T00:13:16.982966Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+Indel_concat_vcf] Task initiated on local node
# [2025-07-23T00:13:16.985495Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+mergeRunStats] Task initiated on local node
# [2025-07-23T00:13:17.132663Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+SNV_concat_vcf' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.132729Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+mergeRunStats' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.132776Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+Indel_concat_vcf' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.133064Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+SNV_index_vcf' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.133262Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+Indel_index_vcf' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.137594Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+SNV_index_vcf] Task initiated on local node
# [2025-07-23T00:13:17.139502Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+Indel_index_vcf] Task initiated on local node
# [2025-07-23T00:13:17.197519Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+Indel_index_vcf' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.197579Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+SNV_index_vcf' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.197866Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Launching command task: 'CallGenome+removeTmpDir' from sub-workflow 'CallGenome'
# [2025-07-23T00:13:17.201553Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskRunner:CallGenome+removeTmpDir] Task initiated on local node
# [2025-07-23T00:13:17.362193Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed command task: 'CallGenome+removeTmpDir' launched from sub-workflow 'CallGenome'
# [2025-07-23T00:13:20.733016Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [TaskManager] Completed sub-workflow task: 'CallGenome' launched from master workflow
# [2025-07-23T00:13:26.956571Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [WorkflowRunner] Strelka somatic workflow successfully completed.
# [2025-07-23T00:13:26.956571Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [WorkflowRunner]
# [2025-07-23T00:13:26.956571Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [WorkflowRunner] 	workflow version: 2.9.10
# [2025-07-23T00:13:26.956846Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [WorkflowRunner]
# [2025-07-23T00:13:26.956859Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [WorkflowRunner] Workflow successfully completed all tasks
# [2025-07-23T00:13:26.956871Z] [notchpeak30.int.chpc.utah.edu] [2031880_1] [WorkflowRunner] Elapsed time for full workflow: 18 sec

# %% [markdown]
# ## Read in results from each caller

# %%
def print_mutations(called_mutations, simulated_mutations, callers, filename=None):
    """
    Prints the mutations found by each caller in a tab-separated format.
    If filename is provided, writes to that file instead of printing to stdout.
    """

    # Prepare header
    head_string = "BP\tMUTATION\tMUTINFO\tSIMULATED"
    caller_names = []
    all_mutations = {}  # not separated by caller
    for caller in callers:
        caller_name = caller.get_name()
        caller_names.append(caller_name)
        head_string += "\t"+caller_name
        for mutation in called_mutations[caller_name]:
            if mutation not in all_mutations:
                all_mutations[mutation] = 0
    
    sorted_mutations = sorted(all_mutations.keys(), key=lambda x: x.split()[0], reverse=False)
    outstring = ""
    for mutation in sorted_mutations:
        outstring += mutation.replace(" ", "\t")
        sim_count = 0
        if mutation in simulated_mutations:
            sim_count = simulated_mutations[mutation].sim_mut_count
        outstring += "\t" + str(sim_count)

        for caller_name in caller_names:
            caller_count = 0
            if caller_name in called_mutations and mutation in called_mutations[caller_name]:
                caller_count = called_mutations[caller_name][mutation]
            outstring += "\t" + str(caller_count)
        outstring += "\n"

    outstring = head_string + "\n" + outstring
    if filename:
        with open(filename, 'w') as f:
            f.write(outstring)
    else:
        print(outstring)
    return outstring

# %% [markdown]
# Now, for a specific example, we can aggregate all of the mutations found by each caller and print them out.

# %%
name, simulated_bam, simulated_control = samples[0]

mutations_by_caller = {} #contains information for each caller
all_mutations = {} # not sorted by caller
for caller in callers:
    caller_name = caller.get_name()
    mutations_by_caller[caller_name] = defaultdict(int)
    caller_passing_indels, caller_all_mutations = caller.get_results(simulated_bam,simulated_control)
    for mutation_name, mutation in caller_all_mutations.items():
        mut_count = mutation.sim_mut_count
        mutations_by_caller[caller_name][mutation_name] = mut_count
        all_mutations[mutation_name] = 1
print_mutations(called_mutations=mutations_by_caller,
    simulated_mutations=simulated_mutations[name], callers=callers)
# Out:
# BP	MUTATION	MUTINFO	SIMULATED	Pindel	Lofreq	VarDict	SomaticSniper	Varscan	Mutect	Strelka
# 831808	S	G	0	0	0	0	0	18	0	0
# 832902	D	5	0	0	0	0	0	12	0	0
# 832981	D	3	0	0	0	0	0	15	0	0
# 833261	S	G	0	0	0	0	0	13	0	0
# 833326	S	G	0	0	0	0	0	16	0	0
# 833628	S	G	0	0	0	0	0	20	0	0
# 833825	S	T	0	0	0	0	0	13	0	0
# 835131	S	C	0	0	0	0	0	27	0	0
# 835362	S	C	0	0	0	1	0	0	0	0
# 835438	S	C	0	0	0	3	0	0	0	2
# 835476	S	T	0	0	0	0	0	0	0	3
# 835662	S	A	0	0	0	1	0	0	0	0
# 835718	D	2	0	2	0	0	0	0	0	0
# 835718	S	G	0	0	0	14	0	11	0	0
# 835732	S	C	0	0	0	2	0	0	0	0
# 835771	S	C	0	0	0	21	0	18	0	0
# 836022	S	T	0	0	0	18	0	17	0	0
# 836180	S	T	0	0	0	1	0	0	0	0
# 836226	S	G	0	0	0	12	0	12	0	0
# 836295	D	1	5	5	5	5	0	0	5	5
# 836367	S	A	0	0	0	1	0	0	0	0
# 836538	D	1	0	20	0	10	0	10	0	0
# 836723	S	T	0	0	0	1	0	0	0	0
# 836753	S	C	0	0	0	1	0	0	0	0
# 836757	D	1	0	2	0	1	0	0	0	0
# 837072	D	1	0	2	0	1	0	0	0	0
# 837083	S	A	0	0	0	13	0	8	0	0
# 837224	S	A	0	0	0	1	0	0	0	0
# 837248	S	T	0	0	0	1	0	0	0	0
# 837365	S	C	0	0	0	1	0	0	0	0
# 838633	S	G	0	0	0	0	0	19	0	0
# 840180	S	T	0	0	0	0	0	13	0	0
# 840250	S	G	0	0	0	0	0	17	0	0
# 840577	I	C	0	0	0	0	0	4	0	0
# 'BP\tMUTATION\tMUTINFO\tSIMULATED\tPindel\tLofreq\tVarDict\tSomaticSniper\tVarscan\tMutect\tStrelka\n831808\tS\tG\t0\t0\t0\t0\t0\t18\t0\t0\n832902\tD\t5\t0\t0\t0\t0\t0\t12\t0\t0\n832981\tD\t3\t0\t0\t0\t0\t0\t15\t0\t0\n833261\tS\tG\t0\t0\t0\t0\t0\t13\t0\t0\n833326\tS\tG\t0\t0\t0\t0\t0\t16\t0\t0\n833628\tS\tG\t0\t0\t0\t0\t0\t20\t0\t0\n833825\tS\tT\t0\t0\t0\t0\t0\t13\t0\t0\n835131\tS\tC\t0\t0\t0\t0\t0\t27\t0\t0\n835362\tS\tC\t0\t0\t0\t1\t0\t0\t0\t0\n835438\tS\tC\t0\t0\t0\t3\t0\t0\t0\t2\n835476\tS\tT\t0\t0\t0\t0\t0\t0\t0\t3\n835662\tS\tA\t0\t0\t0\t1\t0\t0\t0\t0\n835718\tD\t2\t0\t2\t0\t0\t0\t0\t0\t0\n835718\tS\tG\t0\t0\t0\t14\t0\t11\t0\t0\n835732\tS\tC\t0\t0\t0\t2\t0\t0\t0\t0\n835771\tS\tC\t0\t0\t0\t21\t0\t18\t0\t0\n836022\tS\tT\t0\t0\t0\t18\t0\t17\t0\t0\n836180\tS\tT\t0\t0\t0\t1\t0\t0\t0\t0\n836226\tS\tG\t0\t0\t0\t12\t0\t12\t0\t0\n836295\tD\t1\t5\t5\t5\t5\t0\t0\t5\t5\n836367\tS\tA\t0\t0\t0\t1\t0\t0\t0\t0\n836538\tD\t1\t0\t20\t0\t10\t0\t10\t0\t0\n836723\tS\tT\t0\t0\t0\t1\t0\t0\t0\t0\n836753\tS\tC\t0\t0\t0\t1\t0\t0\t0\t0\n836757\tD\t1\t0\t2\t0\t1\t0\t0\t0\t0\n837072\tD\t1\t0\t2\t0\t1\t0\t0\t0\t0\n837083\tS\tA\t0\t0\t0\t13\t0\t8\t0\t0\n837224\tS\tA\t0\t0\t0\t1\t0\t0\t0\t0\n837248\tS\tT\t0\t0\t0\t1\t0\t0\t0\t0\n837365\tS\tC\t0\t0\t0\t1\t0\t0\t0\t0\n838633\tS\tG\t0\t0\t0\t0\t0\t19\t0\t0\n840180\tS\tT\t0\t0\t0\t0\t0\t13\t0\t0\n840250\tS\tG\t0\t0\t0\t0\t0\t17\t0\t0\n840577\tI\tC\t0\t0\t0\t0\t0\t4\t0\t0\n'
